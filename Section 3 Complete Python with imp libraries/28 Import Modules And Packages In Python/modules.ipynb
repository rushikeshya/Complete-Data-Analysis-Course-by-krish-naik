# %%
from package.maths import addition
addition(4,5)
# Out:
# 'The addition of 4 and 5 = 9'

# %%
from package.maths import multiplication
multiplication(4,5)
# Out:
# 'The multiplication of 4 and 5 = 20'

# %%
from package.maths import *
division(4,5)
# Out:
# 'The division of 4 and 5 = 0.8'
